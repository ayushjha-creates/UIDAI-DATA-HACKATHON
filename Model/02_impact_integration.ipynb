# %%
import pandas as pd
import numpy as np

# %%
merged = pd.read_csv("/Users/ayush/Library/Mobile Documents/com~apple~CloudDocs/Developer/UIDAI/02_Cleaned_Data/merged.csv")
risk = pd.read_csv("/Users/ayush/Library/Mobile Documents/com~apple~CloudDocs/Developer/UIDAI/Outputs/risk_predictions.csv")
outliers = pd.read_csv("/Users/ayush/Library/Mobile Documents/com~apple~CloudDocs/Developer/UIDAI/Outputs/high_friction_outliers.csv")

# %%
print("Merged rows:", len(merged))
print("Risk rows:", len(risk))
# Out:
# Merged rows: 4398
# Risk rows: 880

# %%
# Reset indices to guarantee alignment
merged_reset = merged.reset_index(drop=True)
risk_reset = risk.reset_index(drop=True)

# %% [markdown]
# # PRIVACY-PRESERVING AGE VERIFICATION

# %%
# Create age verification table
age_verification_table = merged_reset.copy()
age_verification_table['risk_score'] = risk_reset['risk_score']

# %%
# Age Verification

def verify_age_privately(row, stress_threshold=0.85):

    # If system is under high predicted stress, defer verification
    if row['risk_score'] >= stress_threshold:
        return {
            "eligible": None,
            "status": "deferred_due_to_system_stress"
        }

    # Otherwise return binary eligibility only
    if row['age_18_greater'] > 0:
        return {
            "eligible": True,
            "status": "verified"
        }
    else:
        return {
            "eligible": False,
            "status": "verified"
        }

# %%
# Apply age verification function
age_verification_table['age_verification_result'] = (
    age_verification_table.apply(verify_age_privately, axis=1)
)

# %%
age_verification_table[
    ['state', 'district', 'month', 'risk_score', 'age_verification_result']
]
# Out:
#                             state                  district  month  \
# 0     Andaman and Nicobar Islands                   nicobar      9
# 1     Andaman and Nicobar Islands                   nicobar     10
# 2     Andaman and Nicobar Islands                   nicobar     11
# 3     Andaman and Nicobar Islands                   nicobar     12
# 4     Andaman and Nicobar Islands  north and middle andaman      9
# ...                           ...                       ...    ...
# 4393                  West Bengal            uttar dinajpur     12
# 4394                  West Bengal            west midnapore      9
# 4395                  West Bengal            west midnapore     10
# 4396                  West Bengal            west midnapore     11
# 4397                  West Bengal            west midnapore     12
#
#       risk_score                            age_verification_result
# 0       0.007412          {'eligible': False, 'status': 'verified'}
# 1       0.001601          {'eligible': False, 'status': 'verified'}
# 2       0.025498          {'eligible': False, 'status': 'verified'}
# 3       0.000987          {'eligible': False, 'status': 'verified'}
# 4       0.858008  {'eligible': None, 'status': 'deferred_due_to_...
# ...          ...                                                ...
# 4393         NaN           {'eligible': True, 'status': 'verified'}
# 4394         NaN          {'eligible': False, 'status': 'verified'}
# 4395         NaN          {'eligible': False, 'status': 'verified'}
# 4396         NaN          {'eligible': False, 'status': 'verified'}
# 4397         NaN           {'eligible': True, 'status': 'verified'}
#
# [4398 rows x 5 columns]

# %%
# Summary 
age_verification_table['age_verification_result'].apply(
    lambda x: x['status']
).value_counts()
# Out:
# age_verification_result
# verified                         4372
# deferred_due_to_system_stress      26
# Name: count, dtype: int64

# %%
# final output table
age_verification_output = age_verification_table.copy()

age_verification_output['eligible'] = (
    age_verification_output['age_verification_result']
    .apply(lambda x: x['eligible'])
)

age_verification_output['status'] = (
    age_verification_output['age_verification_result']
    .apply(lambda x: x['status'])
)

age_verification_output = age_verification_output[
    ['state', 'district', 'month', 'risk_score', 'eligible', 'status']
]

# %%
age_verification_output
# Out:
#                             state                  district  month  \
# 0     Andaman and Nicobar Islands                   nicobar      9
# 1     Andaman and Nicobar Islands                   nicobar     10
# 2     Andaman and Nicobar Islands                   nicobar     11
# 3     Andaman and Nicobar Islands                   nicobar     12
# 4     Andaman and Nicobar Islands  north and middle andaman      9
# ...                           ...                       ...    ...
# 4393                  West Bengal            uttar dinajpur     12
# 4394                  West Bengal            west midnapore      9
# 4395                  West Bengal            west midnapore     10
# 4396                  West Bengal            west midnapore     11
# 4397                  West Bengal            west midnapore     12
#
#       risk_score eligible                         status
# 0       0.007412    False                       verified
# 1       0.001601    False                       verified
# 2       0.025498    False                       verified
# 3       0.000987    False                       verified
# 4       0.858008     None  deferred_due_to_system_stress
# ...          ...      ...                            ...
# 4393         NaN     True                       verified
# 4394         NaN    False                       verified
# 4395         NaN    False                       verified
# 4396         NaN    False                       verified
# 4397         NaN     True                       verified
#
# [4398 rows x 6 columns]

# %%
age_verification_output.to_csv(
    "/Users/ayush/Library/Mobile Documents/com~apple~CloudDocs/Developer/UIDAI/Outputs/age_verification_output.csv",
    index=False
)

# %% [markdown]
# # DISASTER RELIEF EARLY WARNING SYSTEM

# %%
# Reset indices to guarantee alignment
disaster_df = merged_reset.copy()
disaster_df['risk_score'] = risk_reset['risk_score']

# %%
# expected update behavior per district

baseline = (
    disaster_df
    .groupby(['state', 'district'], as_index=False)
    .agg(baseline_updates=('total_updates', 'mean'))
)

# %%
# Compare Current Month vs Baseline

disaster_df = disaster_df.merge(
    baseline,
    on=['state', 'district'],
    how='left',
    validate='many_to_one'  # important: sanity check
)

# %%
print("Columns after baseline merge:")
print(disaster_df.columns.tolist())
# Out:
# Columns after baseline merge:
# ['state', 'district', 'year', 'month', 'age_0_5', 'age_5_17', 'age_18_greater', 'demo_age_5_17', 'demo_age_17_', 'bio_age_5_17', 'bio_age_17_', 'total_enrolments', 'total_updates', 'adult_system_stress', 'child_system_stress', 'digital_friction_index', 'log_digital_friction', 'friction_outlier', 'risk_score', 'baseline_updates']

# %%
# update spike ratio calculation
disaster_df['update_spike_ratio'] = (
    disaster_df['total_updates'] /
    (disaster_df['baseline_updates'].fillna(0) + 1)
)

# %%
# Disaster Alert Logic

def disaster_alert(row):
    # Severe displacement + system stress
    if row['update_spike_ratio'] >= 1.8 and row['risk_score'] >= 0.7:
        return "HIGH_ALERT"

    # Early warning (most common)
    elif row['update_spike_ratio'] >= 1.5:
        return "WATCH"

    else:
        return "NORMAL"

# %%
disaster_df['disaster_alert'] = disaster_df.apply(disaster_alert, axis=1)

# %%
disaster_df['disaster_alert'].value_counts()
# Out:
# disaster_alert
# NORMAL    4070
# WATCH      328
# Name: count, dtype: int64

# %%
simulated = disaster_df.copy()
simulated.loc[
    simulated['update_spike_ratio'] > 1.6,
    'update_spike_ratio'
] *= 1.3

simulated['disaster_alert_simulated'] = simulated.apply(disaster_alert, axis=1)

simulated['disaster_alert_simulated'].value_counts()
# Out:
# disaster_alert_simulated
# NORMAL    4070
# WATCH      328
# Name: count, dtype: int64

# %%
# Actionable Alert Table
disaster_alerts = disaster_df[
    disaster_df['disaster_alert'] != "NORMAL"
][
    [
        'state',
        'district',
        'month',
        'total_updates',
        'baseline_updates',
        'update_spike_ratio',
        'risk_score',
        'disaster_alert'
    ]
]

# %%
disaster_alerts.sort_values(
    ['disaster_alert', 'update_spike_ratio'],
    ascending=[True, False]
)
# Out:
#                state            district  month  total_updates  \
# 2540         Manipur         imphal west     11        38933.0
# 4181     Uttarakhand              bijnor     12         1078.0
# 487            Assam           karimganj     12        20642.0
# 2566       Meghalaya     east garo hills      9         1676.0
# 2641       Meghalaya  west jaintia hills      3         3241.0
# ...              ...                 ...    ...            ...
# 3010          Punjab            ludhiana      3        46575.0
# 2454     Maharashtra              raigad     11        10168.0
# 431            Assam            golaghat     11         6053.0
# 2042  Madhya Pradesh           burhanpur      6        14379.0
# 2591       Meghalaya              kamrup      9           85.0
#
#       baseline_updates  update_spike_ratio  risk_score disaster_alert
# 2540      13491.600000            2.885508         NaN          WATCH
# 4181        377.500000            2.848085         NaN          WATCH
# 487        7585.125000            2.721020    0.004149          WATCH
# 2566        630.375000            2.654524         NaN          WATCH
# 2641       1254.777778            2.580871         NaN          WATCH
# ...                ...                 ...         ...            ...
# 3010      30970.444444            1.503805         NaN          WATCH
# 2454       6767.250000            1.502309         NaN          WATCH
# 431        4028.250000            1.502265    0.000259          WATCH
# 2042       9575.125000            1.501547         NaN          WATCH
# 2591         55.666667            1.500000         NaN          WATCH
#
# [328 rows x 8 columns]

# %%
# Final output table
disaster_df['disaster_alert'] = disaster_df.apply(disaster_alert, axis=1)

disaster_df[['state', 'district', 'month', 'risk_score', 'update_spike_ratio', 'disaster_alert']]
# Out:
#                             state                  district  month  \
# 0     Andaman and Nicobar Islands                   nicobar      9
# 1     Andaman and Nicobar Islands                   nicobar     10
# 2     Andaman and Nicobar Islands                   nicobar     11
# 3     Andaman and Nicobar Islands                   nicobar     12
# 4     Andaman and Nicobar Islands  north and middle andaman      9
# ...                           ...                       ...    ...
# 4393                  West Bengal            uttar dinajpur     12
# 4394                  West Bengal            west midnapore      9
# 4395                  West Bengal            west midnapore     10
# 4396                  West Bengal            west midnapore     11
# 4397                  West Bengal            west midnapore     12
#
#       risk_score  update_spike_ratio disaster_alert
# 0       0.007412            1.352219         NORMAL
# 1       0.001601            0.487252         NORMAL
# 2       0.025498            0.966950         NORMAL
# 3       0.000987            1.178470         NORMAL
# 4       0.858008            1.192959         NORMAL
# ...          ...                 ...            ...
# 4393         NaN            0.949020         NORMAL
# 4394         NaN            1.141422         NORMAL
# 4395         NaN            0.822103         NORMAL
# 4396         NaN            1.212187         NORMAL
# 4397         NaN            0.822540         NORMAL
#
# [4398 rows x 6 columns]

# %%
disaster_df[['state', 'district', 'month', 'risk_score', 'update_spike_ratio', 'disaster_alert']].to_csv(
    "/Users/ayush/Library/Mobile Documents/com~apple~CloudDocs/Developer/UIDAI/Outputs/disaster_early_alerts.csv",
    index=False
)

# %% [markdown]
# # AADHAAR KENDRA OPERATIONS & STAFFING OPTIMIZATION

# %%
ops_df = merged_reset.copy()
ops_df['risk_score'] = risk_reset['risk_score']

# %%
# Identify Dominant Stress Type

def dominant_stress(row):
    if row['adult_system_stress'] > row['child_system_stress']:
        return "ADULT"
    elif row['child_system_stress'] > row['adult_system_stress']:
        return "CHILD"
    else:
        return "BALANCED"

# %%
ops_df['dominant_stress'] = ops_df.apply(dominant_stress, axis=1)

# %%
ops_df[['state', 'district', 'month', 'risk_score', 'dominant_stress']]
# Out:
#                             state                  district  month  \
# 0     Andaman and Nicobar Islands                   nicobar      9
# 1     Andaman and Nicobar Islands                   nicobar     10
# 2     Andaman and Nicobar Islands                   nicobar     11
# 3     Andaman and Nicobar Islands                   nicobar     12
# 4     Andaman and Nicobar Islands  north and middle andaman      9
# ...                           ...                       ...    ...
# 4393                  West Bengal            uttar dinajpur     12
# 4394                  West Bengal            west midnapore      9
# 4395                  West Bengal            west midnapore     10
# 4396                  West Bengal            west midnapore     11
# 4397                  West Bengal            west midnapore     12
#
#       risk_score dominant_stress
# 0       0.007412           ADULT
# 1       0.001601           ADULT
# 2       0.025498           ADULT
# 3       0.000987           CHILD
# 4       0.858008           CHILD
# ...          ...             ...
# 4393         NaN           ADULT
# 4394         NaN           ADULT
# 4395         NaN           ADULT
# 4396         NaN           ADULT
# 4397         NaN           ADULT
#
# [4398 rows x 5 columns]

# %%
# Kendra Optimization Rules

def kendra_recommendation(row):
    # Critical overload
    if row['risk_score'] >= 0.85:
        if row['dominant_stress'] == "ADULT":
            return "Add adult biometric operators + extend hours"
        elif row['dominant_stress'] == "CHILD":
            return "Schedule school-hour update camps"
        else:
            return "Deploy mobile enrolment unit"

    # High but manageable stress
    elif row['risk_score'] >= 0.65:
        return "Increase counter capacity during peak hours"

    # Mild stress
    elif row['risk_score'] >= 0.45:
        return "Citizen advisory: visit during off-peak hours"

    # Normal operations
    else:
        return "Normal operations"

# %%
ops_df['kendra_recommendation'] = ops_df.apply(
    kendra_recommendation,
    axis=1
)

# %%
ops_df[['state', 'district', 'month', 'risk_score', 'dominant_stress', 'kendra_recommendation']]
# Out:
#                             state                  district  month  \
# 0     Andaman and Nicobar Islands                   nicobar      9
# 1     Andaman and Nicobar Islands                   nicobar     10
# 2     Andaman and Nicobar Islands                   nicobar     11
# 3     Andaman and Nicobar Islands                   nicobar     12
# 4     Andaman and Nicobar Islands  north and middle andaman      9
# ...                           ...                       ...    ...
# 4393                  West Bengal            uttar dinajpur     12
# 4394                  West Bengal            west midnapore      9
# 4395                  West Bengal            west midnapore     10
# 4396                  West Bengal            west midnapore     11
# 4397                  West Bengal            west midnapore     12
#
#       risk_score dominant_stress              kendra_recommendation
# 0       0.007412           ADULT                  Normal operations
# 1       0.001601           ADULT                  Normal operations
# 2       0.025498           ADULT                  Normal operations
# 3       0.000987           CHILD                  Normal operations
# 4       0.858008           CHILD  Schedule school-hour update camps
# ...          ...             ...                                ...
# 4393         NaN           ADULT                  Normal operations
# 4394         NaN           ADULT                  Normal operations
# 4395         NaN           ADULT                  Normal operations
# 4396         NaN           ADULT                  Normal operations
# 4397         NaN           ADULT                  Normal operations
#
# [4398 rows x 6 columns]

# %%
# Inspect Recommendation Distribution

ops_df['kendra_recommendation'].value_counts()
# Out:
# kendra_recommendation
# Normal operations                                4342
# Add adult biometric operators + extend hours       18
# Citizen advisory: visit during off-peak hours      16
# Increase counter capacity during peak hours        14
# Schedule school-hour update camps                   5
# Deploy mobile enrolment unit                        3
# Name: count, dtype: int64

# %%
# Actionable Operations Table

ops_actions = ops_df[
    ops_df['kendra_recommendation'] != "Normal operations"
][[
    'state',
    'district',
    'month',
    'risk_score',
    'dominant_stress',
    'kendra_recommendation'
]]

# %%
ops_actions.sort_values(
    'risk_score',
    ascending=False
)
# Out:
#                            state                  district  month  risk_score  \
# 214               Andhra Pradesh                 vikarabad      9    0.983939
# 570                        Assam   south salmara mankachar     11    0.980257
# 152               Andhra Pradesh                narayanpet     10    0.979604
# 242               Andhra Pradesh             west godavari     11    0.976174
# 425                        Assam                  golaghat      4    0.974702
# 328            Arunachal Pradesh               west kameng     10    0.972611
# 528                        Assam                   nalbari      5    0.971945
# 237               Andhra Pradesh            warangal rural     11    0.964071
# 123               Andhra Pradesh              mahabubnagar     10    0.960151
# 396                        Assam                   dhemaji      9    0.957097
# 109               Andhra Pradesh                   krishna      9    0.939875
# 70                Andhra Pradesh                  jagitial     10    0.939051
# 542                        Assam          north garo hills      7    0.936258
# 460                        Assam                    kamrup      9    0.935480
# 727                        Bihar                    munger     10    0.934579
# 205               Andhra Pradesh                srikakulam     10    0.930775
# 590                        Assam        west karbi anglong      5    0.923159
# 161               Andhra Pradesh                   nellore     12    0.918172
# 83                Andhra Pradesh          jogulamba gadwal     11    0.914552
# 795                        Bihar                   sheohar     10    0.887094
# 319            Arunachal Pradesh               upper siang     10    0.886377
# 723                        Bihar                    munger      4    0.878478
# 186               Andhra Pradesh          rajanna sircilla     12    0.873084
# 692                        Bihar                   katihar     10    0.872643
# 4    Andaman and Nicobar Islands  north and middle andaman      9    0.858008
# 356                        Assam                bongaigaon      3    0.850841
# 534                        Assam        north cachar hills      5    0.834212
# 397                        Assam                   dhemaji     10    0.832159
# 412                        Assam                 dibrugarh      7    0.825741
# 164               Andhra Pradesh                    nirmal     11    0.782655
# 153               Andhra Pradesh                narayanpet     11    0.758554
# 610                        Bihar                aurangabad     11    0.741498
# 171               Andhra Pradesh      parvathipuram manyam     10    0.738851
# 195               Andhra Pradesh                  siddipet     12    0.732592
# 108               Andhra Pradesh             komaram bheem     12    0.732331
# 573                        Assam                  tinsukia      4    0.716542
# 633                        Bihar                   bhojpur     11    0.689161
# 267            Arunachal Pradesh                east siang     11    0.681625
# 222               Andhra Pradesh             visakhapatnam     12    0.680107
# 18                Andhra Pradesh     alluri sitharama raju     11    0.676468
# 357                        Assam                bongaigaon      4    0.629751
# 540                        Assam        north cachar hills     12    0.624098
# 110               Andhra Pradesh                   krishna     10    0.596830
# 733                        Bihar               muzaffarpur      6    0.595351
# 115               Andhra Pradesh                   kurnool     10    0.581293
# 281            Arunachal Pradesh                  longding      7    0.579389
# 533                        Assam        north cachar hills      4    0.572641
# 100               Andhra Pradesh                karimnagar     12    0.528883
# 624                        Bihar                 bhagalpur      6    0.528105
# 591                        Assam        west karbi anglong      6    0.526057
# 647                        Bihar            east champaran      6    0.508829
# 677                        Bihar                 jehanabad      9    0.507960
# 643                        Bihar                 darbhanga     12    0.501598
# 102               Andhra Pradesh                   khammam     10    0.497057
# 302            Arunachal Pradesh                papum pare      9    0.470459
# 743                        Bihar                   nalanda     11    0.464121
#
#     dominant_stress                          kendra_recommendation
# 214           ADULT   Add adult biometric operators + extend hours
# 570           ADULT   Add adult biometric operators + extend hours
# 152           ADULT   Add adult biometric operators + extend hours
# 242           ADULT   Add adult biometric operators + extend hours
# 425           CHILD              Schedule school-hour update camps
# 328           ADULT   Add adult biometric operators + extend hours
# 528           CHILD              Schedule school-hour update camps
# 237        BALANCED                   Deploy mobile enrolment unit
# 123           ADULT   Add adult biometric operators + extend hours
# 396           ADULT   Add adult biometric operators + extend hours
# 109           ADULT   Add adult biometric operators + extend hours
# 70         BALANCED                   Deploy mobile enrolment unit
# 542        BALANCED                   Deploy mobile enrolment unit
# 460           ADULT   Add adult biometric operators + extend hours
# 727           ADULT   Add adult biometric operators + extend hours
# 205           CHILD              Schedule school-hour update camps
# 590           ADULT   Add adult biometric operators + extend hours
# 161           ADULT   Add adult biometric operators + extend hours
# 83            ADULT   Add adult biometric operators + extend hours
# 795           ADULT   Add adult biometric operators + extend hours
# 319           ADULT   Add adult biometric operators + extend hours
# 723           CHILD              Schedule school-hour update camps
# 186           ADULT   Add adult biometric operators + extend hours
# 692           ADULT   Add adult biometric operators + extend hours
# 4             CHILD              Schedule school-hour update camps
# 356           ADULT   Add adult biometric operators + extend hours
# 534           CHILD    Increase counter capacity during peak hours
# 397           ADULT    Increase counter capacity during peak hours
# 412           CHILD    Increase counter capacity during peak hours
# 164        BALANCED    Increase counter capacity during peak hours
# 153           ADULT    Increase counter capacity during peak hours
# 610           ADULT    Increase counter capacity during peak hours
# 171           ADULT    Increase counter capacity during peak hours
# 195        BALANCED    Increase counter capacity during peak hours
# 108        BALANCED    Increase counter capacity during peak hours
# 573           CHILD    Increase counter capacity during peak hours
# 633           ADULT    Increase counter capacity during peak hours
# 267           CHILD    Increase counter capacity during peak hours
# 222           ADULT    Increase counter capacity during peak hours
# 18            ADULT    Increase counter capacity during peak hours
# 357           CHILD  Citizen advisory: visit during off-peak hours
# 540           ADULT  Citizen advisory: visit during off-peak hours
# 110           CHILD  Citizen advisory: visit during off-peak hours
# 733           ADULT  Citizen advisory: visit during off-peak hours
# 115           CHILD  Citizen advisory: visit during off-peak hours
# 281           ADULT  Citizen advisory: visit during off-peak hours
# 533           CHILD  Citizen advisory: visit during off-peak hours
# 100           ADULT  Citizen advisory: visit during off-peak hours
# 624           ADULT  Citizen advisory: visit during off-peak hours
# 591           ADULT  Citizen advisory: visit during off-peak hours
# 647           ADULT  Citizen advisory: visit during off-peak hours
# 677           ADULT  Citizen advisory: visit during off-peak hours
# 643           ADULT  Citizen advisory: visit during off-peak hours
# 102           ADULT  Citizen advisory: visit during off-peak hours
# 302           CHILD  Citizen advisory: visit during off-peak hours
# 743           ADULT  Citizen advisory: visit during off-peak hours

# %%
ops_actions.to_csv(
    "/Users/ayush/Library/Mobile Documents/com~apple~CloudDocs/Developer/UIDAI/Outputs/kendra_optimization_recommendations.csv",
    index=False
)
